# %% [markdown]
# # 1. Real-time Profile Update to PostgreSQL
# 𝐓𝐚𝐬𝐤 𝐃𝐞𝐬𝐜𝐫𝐢𝐩𝐭𝐢𝐨𝐧:
# Whenever a new user signs up, their profile information needs to be fetched from the API and inserted into a PostgreSQL database if their fid (profile ID) does not already exist. Additionally, this function will regularly check and update the database every specified number of seconds.
#
#
#
# Steps:
# - Set up the PostgreSQL database with the necessary schema.
# - Implement a function to fetch user profiles from the API with the maximum id in the PostgreSQL.
# - The new fid to check whether a new user is found in the Platform or not is `MaxFid(from sql) + 1`,
# - Do recursively: `newFid = MaxFid + 1, maxFid = newFid`, until not user is found with the given fid.
# - Check if the user profile (fid) already exists in the database.
# - If not, insert the new profile into the database.
# - Implement a scheduled task to run this function every specified number of seconds.
#
#
#
# Estimated Time: 10 hours

# %% [markdown]
# # 2. Retrieve All Profiles Periodically
# 𝐓𝐚𝐬𝐤 𝐃𝐞𝐬𝐜𝐫𝐢𝐩𝐭𝐢𝐨𝐧:
# Fetch and store profile information for all fids into a separate PostgreSQL database, updating this information every week or as per a specified interval.
#
#
#
# Steps:
# - Create a separate PostgreSQL database or table for storing all profiles.
# - Develop a function to fetch profile data for each fid in the platform and update the database accordingly. To do that run a binary search algorithm to find the maximum Fid in the platform. <br>
# - Then run the API from `Fid = 0 to Fid = maxFid.`
# - Schedule this function to run periodically (weekly or other specified interval) to update all profiles.
#
#
#
# Estimated Time: 8 hours

# %% [markdown]
# # 3. Post a Follow Request
# 𝐓𝐚𝐬𝐤 𝐃𝐞𝐬𝐜𝐫𝐢𝐩𝐭𝐢𝐨𝐧:
# Develop a function that sends a follow request for a specified fid.
#
#
#
# Steps:
# - Fetch users fromt the All profiles PostgreSQL database that has is_followed=false
# - Implement a function to send a follow request to a specified endpoint.
# - Update the PostgreSQL database with `is_followed=true`
# - Ensure proper authentication and error handling mechanisms are in place.
#
#
#
# Estimated Time: 4 hours

# %% [markdown]
# # 4. Retrieve Messages and Store in PostgreSQL
# 𝐓𝐚𝐬𝐤 𝐃𝐞𝐬𝐜𝐫𝐢𝐩𝐭𝐢𝐨𝐧:
# Fetch messages based on fid number and store them in PostgreSQL without duplicating entries. The function should include filters for message or date limits.
#
#
#
# Steps:
# - Set up or modify an existing PostgreSQL database to store messages.
# - Develop a function to fetch messages with parameters for limiting by number of messages or date.
# - Implement checks to prevent storing duplicate messages.
# - Store retrieved messages in the database.
#
#
#
# Estimated Time: 8 hours
#
#
#
# Total Estimated Time: 30 hours

# %% [markdown]
# # 𝐀𝐝𝐝𝐢𝐭𝐢𝐨𝐧𝐚𝐥 𝐂𝐨𝐧𝐬𝐢𝐝𝐞𝐫𝐚𝐭𝐢𝐨𝐧𝐬:
# i. Testing and Quality Assurance: Add approximately 5-8 hours to the estimate for thorough testing and debugging of all functionalities.
# ii. Documentation: Spend 2-3 hours documenting the codebase and usage instructions for future reference or for other developers.
# iii. Deployment and Integration: Consider potential time for deploying these functions into a live environment and integrating with existing systems. This could add a few more hours depending on the complexity of the client's infrastructure.
#
#
#
# It will take 40+ hours.

# %% [markdown]
# # **Here is the steps:**
# ### **Assumption: Every user has at least one channel that he/she follows**
# * 1. Get all channels in the warpcast platform
# * 2. For each channel there are followers. Find those followers.
# * 3. Now, I can follow those followers by sending a follow POST request.
# ##### **You can see the demo in the video that I sent you in the Upwork messaging room.**

# %% [markdown]
# # Here is an example
# ### **Get all the channels**

# %%
import json
import requests

# %%
import requests

# Make the GET request to the API endpoint
all_channels_response = requests.get('https://api.warpcast.com/v2/all-channels')

# Check if the request was successful
if all_channels_response.status_code == 200:
    # Parse the JSON response
    all_channels_data = all_channels_response.json()
    
    # Navigate through the JSON to extract 'channels'
    channels = all_channels_data['result']['channels']
    
    # Extract and print some of the channel IDs
    channel_ids = [channel['id'] for channel in channels]
    print(len(channel_ids))
    print("Channel IDs:", channel_ids[:100])
else:
    # Print the error code if the request failed
    print("Failed to retrieve data. Status code:", all_channels_response.status_code)
# Out:
# 9494
# Channel IDs: ['ballooncast', 'johnwang', 'praxisveritas', '300', 'm2e', 'arigatou', 'freestyle', 'bookworms', 'mountainlife', 'mooncast', 'zielchain', 'wowcast', 'downshift', 'ocean-shore', 'degenfrens', 'krow', 'hatterdasher', 'everyone', 'outercorps', 'teslamotors', 'artistssupport', 'nextjs', 'betbase', 'degencafe', 'art-renaissance', 'basenft', 'ham2win', 'confucius-say', 'never-written', 'louhorn', 'koreankol', 'koldev', 'memetics', 'point', 'treasury', 'selfsovereign', 'knight', 'rank', 'leaderboard', 'score', 'founder', 'hs', 'eu-acc', 'raz', 'alfatech', 'basenigeria', 'liberty', 'airgraph', 'dune-bounties', 'tocd-jp', 'geophysics', 'movieclips', 'orsunao', 'roolz', 'church-of-love', 'hpchain', 'ghostyverse', 'replyke', 'gen-art-sales', 'toshian', 'farcards-devs', 'blockchainjp', '8pepen', 'ethforall', 'holistic', 'cats-and-pets', 'biomimicry', 'artcalls', 'farmon', 'hellno', 'button', 'buttongame', 'investment', 'intelligent', 'forest', 'agust', 'coke-zero', 'purple-updates', 'alfafrens-ko', 'basics', 'labs', 'korea-chiikawa', 'zoodao', 'hanjul-economy', 'outandabout', 'lollipop', 'feature', 'drive', 'hoppyonbase', 'obaketengoku', 'memecoinmadness', 'darrylyeo', 'rugdotfun', 'kubera', 'eigenfoundation', 'blend-o-rama', 'graphic-notation', 'onchain-studios', 'genfinity-news', 'switchboard']

# %% [markdown]
# # **Get all followers of the specific channel**

# %%
# # Make the GET request to the API endpoint
# all_followers_response = requests.get('https://api.warpcast.com/v1/channel-followers?channelId={}'.format(channel_ids[100]))

# # Check if the request was successful
# if all_followers_response.status_code == 200:
#     # Parse the JSON response
#     all_followers_data = all_followers_response.json()
    
#     # Navigate through the JSON to extract 'channels'
#     users = all_followers_data['result']['users']
    
#     # Extract and print some of the followers IDs
#     users_id = [user['fid'] for user in users]
#     print("user IDs:", users_id[:100])
# else:
#     # Print the error code if the request failed
#     print("Failed to retrieve data. Status code:", all_followers_response.status_code)

# %%
import time
def fetch_data(url):
    response = requests.get(url)
    data = response.json()
    return data

def get_followers(base_url):
    next_url = base_url
    follower_ids = []
    while next_url:
        time.sleep(1)
        data = fetch_data(next_url)
        followers = data['result']['users']
        for follower in followers:
            follower_ids.append(follower['fid'])
        if 'next' in data:
            next_cursor = data['next']['cursor']
            next_url = base_url + "&cursor=" + next_cursor
        else:
            next_url = None
        
    return follower_ids

# Base URL of the API (replace with actual URL)
all_users = []
count = 0
for channel_id in channel_ids:
    base_url = "https://api.warpcast.com/v1/channel-followers?channelId={}".format(channel_id)
    followers = get_followers(base_url)
    all_users.extend(followers)
    count += 1
    if count%100 == 0:
        print(len(all_users))
print(len(all_users))

# %% [markdown]
# # **Follow the specific user**

# %%
import requests # type: ignore
import json
my_id = 506144
user_id = 508855
url = "https://client.warpcast.com/v2/follows" 

headers = {
    "Authorization": "Bearer MK-s1EcIl87La9zaBBWPdrZ9bPzxWcDCWDB5CMJTJR2Qm19zVpxg91drvCYkelvFIEhY9//fXS0ozkA3qgL0W4fsQ==",
    "Content-Type": "application/json; charset=utf-8",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36"
}

data = {
    "targetFid": "{}".format(user_id),
    "e": json.dumps([{
        "user_id": "{}".format(my_id)
    }])
}

# Sending the PUT request
response = requests.put(url, json=data, headers=headers)

# Print the status code and response data
print("Status Code:", response.status_code)
print("Response Body:", response.text)
# Out:
# Status Code: 200
# Response Body: {"result":{"success":true,"userAppContext":{"canAddLinks":true}}}

# %% [markdown]
# # **Get posts**

# %%
url = 
response = requests.get(url)
data = response.json()
next_cursor = data['result'].get('next_cursor')

# %%
fid = 354669

# %%
import requests
response = requests.get("https://api.warpcast.com/v2/user?fid={}".format(fid))
response.status_code
# Out:
# 200

# %%
import time
def fetch_data(url):
    response = requests.get(url)
    data = response.json()
    return data

def get_total_casts(base_url):
    total_casts = 0
    next_url = base_url

    while next_url:
        time.sleep(4)
        data = fetch_data(next_url)
        total_casts += len(data['result']['casts'])
        if 'next' in data:
            next_cursor = data['next']['cursor']
            next_url = base_url + "&cursor=" + next_cursor
        else:
            next_url = None
    return total_casts

# Base URL of the API (replace with actual URL)
for fid in ['461094', '460944', '362022', '449603']:
    base_url = "https://client.warpcast.com/v2/casts?fid={}".format(fid)
    total_casts = get_total_casts(base_url)
    print("Total number of casts of user with fid = {}: {} ".format(fid, total_casts))

# %%
from datetime import datetime


def populate_casts(cast_data):
    cast.casts_hash = cast_data.get('hash')
    cast.thread_hash = cast_data.get('threadHash')
    cast.parent_source_type = cast_data.get('parentSource', {}).get('type')
    cast.parent_source_url = cast_data.get('parentSource', {}).get('url')
    cast.author_fid = cast_data.get('author', {}).get('fid')
    cast.author_username = cast_data.get('author', {}).get('username')
    cast.author_display_name = cast_data.get('author', {}).get('displayName')
    cast.author_pfp_url = cast_data.get('author', {}).get('pfp', {}).get('url')
    cast.author_pfp_verified = cast_data.get('author', {}).get('pfp', {}).get('verified', False)
    cast.author_profile_bio = cast_data.get('author', {}).get('profile', {}).get('bio', {}).get('text', '')
    cast.author_profile_location_description = cast_data.get('author', {}).get('profile', {}).get('location', {}).get('description', '')
    cast.author_follower_count = cast_data.get('author', {}).get('followerCount', 0)
    cast.author_following_count = cast_data.get('author', {}).get('followingCount', 0)
    cast.author_active_on_fc_network = cast_data.get('author', {}).get('activeOnFcNetwork', False)
    cast.message_text = cast_data.get('text', '')
    cast.embeds__images_type = cast_data.get('embeds', {}).get('images', [{}])[0].get('type')
    cast.embeds_images_url = cast_data.get('embeds', {}).get('images', [{}])[0].get('url')
    cast.embeds_images_source_url = cast_data.get('embeds', {}).get('images', [{}])[0].get('sourceUrl')
    cast.embeds_images_alt = cast_data.get('embeds', {}).get('images', [{}])[0].get('alt')
    cast.timestamp = cast_data.get('timestamp',  datetime.now())
    cast.replies_count = cast_data.get('replies', {}).get('count', 0)
    cast.reactions_count = cast_data.get('reactions', {}).get('count', 0)
    cast.recasts_count = cast_data.get('recasts', {}).get('count', 0)
    cast.watches_count = cast_data.get('watches', {}).get('count', 0)
    cast.tags_type = cast_data.get('tags', [{}])[0].get('type')
    cast.tags_id = cast_data.get('tags', [{}])[0].get('id')
    cast.tags_name = cast_data.get('tags', [{}])[0].get('name')
    cast.tags_image_url = cast_data.get('tags', [{}])[0].get('imageUrl', '')

# %%
fid = 508826
limit = 100
import requests # type: ignore
response = requests.get("https://client.warpcast.com/v2/casts?fid={}&limit={}".format(fid, limit))
data = response.json()
data['result']['casts']
# Out:
# [{'hash': '0x765e3c08a555f32778e5e41a8233382c22344243',
#   'threadHash': '0x765e3c08a555f32778e5e41a8233382c22344243',
#   'parentSource': {'type': 'url',
#    'url': 'chain://eip155:7777777/erc721:0x22be981fb87effbe6780b34a6fe1dfc14a00ec8e'},
#   'author': {'fid': 508826,
#    'username': 'abbeydinho',
#    'displayName': 'Abbeydinho',
#    'pfp': {'url': 'https://imagedelivery.net/BXluQx4ige9GuW0Ia56BHw/007bf8cb-1869-4442-d69e-445024a7b800/rectcrop3',
#     'verified': False},
#    'profile': {'bio': {'text': '', 'mentions': [], 'channelMentions': []},
#     'location': {'placeId': '', 'description': ''}},
#    'followerCount': 51,
#    'followingCount': 102,
#    'activeOnFcNetwork': False},
#   'text': 'Alone we can do so little, together we can do so much, never walk alone',
#   'timestamp': 1714634278000,
#   'replies': {'count': 1},
#   'reactions': {'count': 17},
#   'recasts': {'count': 7, 'recasters': []},
#   'watches': {'count': 0},
#   'tags': [{'type': 'channel',
#     'id': 'design',
#     'name': 'Design',
#     'imageUrl': 'https://i.imgur.com/4PDpB2a.gif'}],
#   'quoteCount': 0,
#   'combinedRecastCount': 7},
#  {'hash': '0x3d7e76d1fef0cbcb8fbb438534ec7b32aa5afb03',
#   'threadHash': '0x3d7e76d1fef0cbcb8fbb438534ec7b32aa5afb03',
#   'parentSource': {'type': 'url',
#    'url': 'https://warpcast.com/~/channel/steaktoken'},
#   'author': {'fid': 508826,
#    'username': 'abbeydinho',
#    'displayName': 'Abbeydinho',
#    'pfp': {'url': 'https://imagedelivery.net/BXluQx4ige9GuW0Ia56BHw/007bf8cb-1869-4442-d69e-445024a7b800/rectcrop3',
#     'verified': False},
#    'profile': {'bio': {'text': '', 'mentions': [], 'channelMentions': []},
#     'location': {'placeId': '', 'description': ''}},
#    'followerCount': 51,
#    'followingCount': 102,
#    'activeOnFcNetwork': False},
#   'text': 'We all have dreams. But in order to make dreams come into reality, it takes an awful lot of determination, dedication, self-discipline, and effort.',
#   'timestamp': 1714633482000,
#   'replies': {'count': 0},
#   'reactions': {'count': 17},
#   'recasts': {'count': 5, 'recasters': []},
#   'watches': {'count': 0},
#   'tags': [{'type': 'channel',
#     'id': 'steaktoken',
#     'name': 'steaktoken',
#     'imageUrl': 'https://imagedelivery.net/BXluQx4ige9GuW0Ia56BHw/9405fd70-2daf-4079-104d-77c4b3591f00/rectcrop3'}],
#   'quoteCount': 0,
#   'combinedRecastCount': 5},
#  {'hash': '0xc9a9ffa41eecced536885ab66495b93e2f372172',
#   'threadHash': '0xc9a9ffa41eecced536885ab66495b93e2f372172',
#   'parentSource': {'type': 'url', 'url': 'https://warpcast.com/~/channel/lp'},
#   'author': {'fid': 508826,
#    'username': 'abbeydinho',
#    'displayName': 'Abbeydinho',
#    'pfp': {'url': 'https://imagedelivery.net/BXluQx4ige9GuW0Ia56BHw/007bf8cb-1869-4442-d69e-445024a7b800/rectcrop3',
#     'verified': False},
#    'profile': {'bio': {'text': '', 'mentions': [], 'channelMentions': []},
#     'location': {'placeId': '', 'description': ''}},
#    'followerCount': 51,
#    'followingCount': 102,
#    'activeOnFcNetwork': False},
#   'text': "My approach is just fearless. I'm not afraid to try anything.",
#   'timestamp': 1714632890000,
#   'replies': {'count': 0},
#   'reactions': {'count': 18},
#   'recasts': {'count': 5, 'recasters': []},
#   'watches': {'count': 0},
#   'tags': [{'type': 'channel',
#     'id': 'lp',
#     'name': 'HAM 🍖',
#     'imageUrl': 'https://i.imgur.com/vC00Vn0.png'}],
#   'quoteCount': 0,
#   'combinedRecastCount': 5},
#  {'hash': '0x932afd5d256de10c003d2b4a13c5f6b6fc82ace6',
#   'threadHash': '0x932afd5d256de10c003d2b4a13c5f6b6fc82ace6',
#   'parentSource': {'type': 'url',
#    'url': 'chain://eip155:7777777/erc721:0x5d6a07d07354f8793d1ca06280c4adf04767ad7e'},
#   'author': {'fid': 508826,
#    'username': 'abbeydinho',
#    'displayName': 'Abbeydinho',
#    'pfp': {'url': 'https://imagedelivery.net/BXluQx4ige9GuW0Ia56BHw/007bf8cb-1869-4442-d69e-445024a7b800/rectcrop3',
#     'verified': False},
#    'profile': {'bio': {'text': '', 'mentions': [], 'channelMentions': []},
#     'location': {'placeId': '', 'description': ''}},
#    'followerCount': 51,
#    'followingCount': 102,
#    'activeOnFcNetwork': False},
#   'text': "Once you replace negative thoughts with positive ones, you'll start having positive results",
#   'timestamp': 1714632372000,
#   'replies': {'count': 0},
#   'reactions': {'count': 18},
#   'recasts': {'count': 7, 'recasters': []},
#   'watches': {'count': 0},
#   'tags': [{'type': 'channel',
#     'id': 'degen',
#     'name': 'Degen',
#     'imageUrl': 'https://ipfs.decentralized-content.com/ipfs/bafkreieudzvadtjy36j7x2i73isqw2jmgbwtum3p3eaahn4mnztuzl7y7e'}],
#   'quoteCount': 0,
#   'combinedRecastCount': 7},
#  {'hash': '0xa99fbe501566d8ce7a9d3dfdffa274177bf0a75a',
#   'threadHash': '0xa99fbe501566d8ce7a9d3dfdffa274177bf0a75a',
#   'parentSource': {'type': 'url',
#    'url': 'chain://eip155:1/erc721:0xca21d4228cdcc68d4e23807e5e370c07577dd152'},
#   'author': {'fid': 508826,
#    'username': 'abbeydinho',
#    'displayName': 'Abbeydinho',
#    'pfp': {'url': 'https://imagedelivery.net/BXluQx4ige9GuW0Ia56BHw/007bf8cb-1869-4442-d69e-445024a7b800/rectcrop3',
#     'verified': False},
#    'profile': {'bio': {'text': '', 'mentions': [], 'channelMentions': []},
#     'location': {'placeId': '', 'description': ''}},
#    'followerCount': 51,
#    'followingCount': 102,
#    'activeOnFcNetwork': False},
#   'text': "Living with fear stops us taking risks, and if you don't go out on the branch, you're never going to get the best fruit",
#   'timestamp': 1714630656000,
#   'replies': {'count': 0},
#   'reactions': {'count': 21},
#   'recasts': {'count': 7, 'recasters': []},
#   'watches': {'count': 0},
#   'tags': [{'type': 'channel',
#     'id': 'zora',
#     'name': 'Zora',
#     'imageUrl': 'https://i.imgur.com/3BN8GSF.png'}],
#   'quoteCount': 0,
#   'combinedRecastCount': 7},
#  {'hash': '0xc60139b2212f718ac3d9ba5b91626d67eb878cf8',
#   'threadHash': '0xc60139b2212f718ac3d9ba5b91626d67eb878cf8',
#   'parentSource': {'type': 'url',
#    'url': 'https://warpcast.com/~/channel/poem'},
#   'author': {'fid': 502433,
#    'username': 'ayomide1',
#    'displayName': 'Ojuri Iyanuoluwa',
#    'pfp': {'url': 'https://imagedelivery.net/BXluQx4ige9GuW0Ia56BHw/dca52f40-4f14-4736-cf24-2da132a26500/rectcrop3',
#     'verified': False},
#    'profile': {'bio': {'text': 'Fun to be with',
#      'mentions': [],
#      'channelMentions': []},
#     'location': {'placeId': '', 'description': ''}},
#    'followerCount': 142,
#    'followingCount': 259,
#    'activeOnFcNetwork': False},
#   'text': 'Golden sunsets paint the sky,\nSoftly fading, as the day says goodbye.\nThe stars appear, like diamonds bright,\nA night of rest, under their gentle light.\n\n\nCopyright',
#   'timestamp': 1714552543000,
#   'replies': {'count': 0},
#   'reactions': {'count': 18},
#   'recasts': {'count': 2,
#    'recasters': [{'fid': 508826,
#      'username': 'abbeydinho',
#      'displayName': 'Abbeydinho',
#      'recastHash': '0x00'}]},
#   'watches': {'count': 0},
#   'recast': True,
#   'tags': [{'type': 'channel',
#     'id': 'poem',
#     'name': 'Poem',
#     'imageUrl': 'https://i.imgur.com/dF9qvYL.jpg'}],
#   'quoteCount': 0,
#   'combinedRecastCount': 2},
#  {'hash': '0xa12e2ad42d3d726911cfc465bc74a18142212891',
#   'threadHash': '0xa12e2ad42d3d726911cfc465bc74a18142212891',
#   'parentSource': {'type': 'url',
#    'url': 'https://warpcast.com/~/channel/forecast'},
#   'author': {'fid': 281836,
#    'username': 'imthedude',
#    'displayName': 'dude↑🔵 🎩',
#    'pfp': {'url': 'https://i.imgur.com/AhI14F2.png', 'verified': False},
#    'profile': {'bio': {'text': "i’m the dude. i make art. i make memes. but, i don't make money. creatooor /actions /dude /designershumor /dankmemes /forecast /graphicdesign  /getmotivated",
#      'mentions': [],
#      'channelMentions': ['actions',
#       'dude',
#       'designershumor',
#       'dankmemes',
#       'forecast',
#       'graphicdesign',
#       'getmotivated']},
#     'location': {'placeId': '', 'description': ''}},
#    'followerCount': 19750,
#    'followingCount': 3390,
#    'activeOnFcNetwork': True,
#    'badges': [{'type': 'top-user-in-channel',
#      'content': {'topUserInChannel': {'url': 'https://warpcast.com/~/channel/forecast',
#        'warpcastUrl': 'https://warpcast.com/~/channel/forecast',
#        'imageUrl': 'https://imagedelivery.net/BXluQx4ige9GuW0Ia56BHw/4c089109-ceb0-4e77-af0a-6694c5d67900/original',
#        'fastImageUrl': 'https://imagedelivery.net/BXluQx4ige9GuW0Ia56BHw/4c089109-ceb0-4e77-af0a-6694c5d67900/original',
#        'channelKey': 'forecast'}}}]},
#   'text': '/forecast',
#   'timestamp': 1714565167000,
#   'channelMentions': [{'key': 'forecast', 'name': 'forecast 🔮'}],
#   'embeds': {'images': [{'type': 'image',
#      'url': 'https://imagedelivery.net/BXluQx4ige9GuW0Ia56BHw/faf16e7f-7828-4e3b-31b7-646cff4d6700/original',
#      'sourceUrl': 'https://imagedelivery.net/BXluQx4ige9GuW0Ia56BHw/faf16e7f-7828-4e3b-31b7-646cff4d6700/original',
#      'media': {'version': '2',
#       'width': 2545,
#       'height': 1352,
#       'staticRaster': 'https://imagedelivery.net/BXluQx4ige9GuW0Ia56BHw/faf16e7f-7828-4e3b-31b7-646cff4d6700/original'},
#      'alt': 'Cast image embed'}],
#    'urls': [],
#    'videos': [],
#    'unknowns': [],
#    'processedCastText': '/forecast'},
#   'replies': {'count': 46},
#   'reactions': {'count': 166},
#   'recasts': {'count': 23,
#    'recasters': [{'fid': 508826,
#      'username': 'abbeydinho',
#      'displayName': 'Abbeydinho',
#      'recastHash': '0x00'},
#     {'fid': 281836,
#      'username': 'imthedude',
#      'displayName': 'dude↑🔵 🎩',
#      'recastHash': '0x348ff4766a7e300aed63d0700774ad65d10e51b5'}]},
#   'watches': {'count': 0},
#   'recast': True,
#   'tags': [{'type': 'channel',
#     'id': 'forecast',
#     'name': 'forecast 🔮',
#     'imageUrl': 'https://imagedelivery.net/BXluQx4ige9GuW0Ia56BHw/4c089109-ceb0-4e77-af0a-6694c5d67900/original'}],
#   'viewCount': 1900,
#   'quoteCount': 1,
#   'combinedRecastCount': 24},
#  {'hash': '0x7ca121642649beaf350eb3575033d375e1ebe0bf',
#   'threadHash': '0x7ca121642649beaf350eb3575033d375e1ebe0bf',
#   'parentSource': {'type': 'url', 'url': 'https://warpcast.com/~/channel/lp'},
#   'author': {'fid': 4482,
#    'username': 'deployer',
#    'displayName': 'Deployer 🍖🎩',
#    'pfp': {'url': 'https://i.imgur.com/y7BDXNg.jpg', 'verified': False},
#    'profile': {'bio': {'text': 'Currently deploying. Unofficial head platypus of /lp ',
#      'mentions': [],
#      'channelMentions': ['lp']},
#     'location': {'placeId': 'ChIJ00mFOjZ5hYARk-l1ppUV6pQ',
#      'description': 'Berkeley, CA, USA'}},
#    'followerCount': 26164,
#    'followingCount': 551,
#    'activeOnFcNetwork': True,
#    'badges': [{'type': 'top-user-in-channel',
#      'content': {'topUserInChannel': {'url': 'https://warpcast.com/~/channel/lp',
#        'warpcastUrl': 'https://warpcast.com/~/channel/lp',
#        'imageUrl': 'https://i.imgur.com/vC00Vn0.png',
#        'fastImageUrl': 'https://res.cloudinary.com/merkle-manufactory/image/fetch/c_fill,f_png/https%3A%2F%2Fi.imgur.com%2FvC00Vn0.png',
#        'channelKey': 'lp'}}}]},
#   'text': "you've asked for it and now it has arrived. a cast action to tip that sweet ham! install the cast action and let me know what you think. it tips 100 🍖\n\nhttps://frames.neynar.com/f/fa1a923a/8fcba296",
#   'timestamp': 1713645225000,
#   'embeds': {'images': [],
#    'urls': [{'type': 'url',
#      'openGraph': {'url': 'https://frames.neynar.com/f/fa1a923a/8fcba296',
#       'sourceUrl': 'https://frames.neynar.com/f/fa1a923a/8fcba296',
#       'title': 'Page 1',
#       'domain': 'frames.neynar.com',
#       'image': 'https://i.imgur.com/NCSPg01.png',
#       'useLargeImage': False,
#       'frame': {'version': 'vNext',
#        'imageUrl': 'https://proxy.wrpcd.net/?url=https%3A%2F%2Fi.imgur.com%2FNCSPg01.png&s=20910206af51f35ba3d5534e269f4607e5a853f12e17503e4f84db00f82ec806',
#        'postUrl': 'https://frames.neynar.com/f/fa1a923a/8fcba296',
#        'buttons': [{'index': 1,
#          'title': 'Install Ham',
#          'type': 'post_redirect'}],
#        'imageAspectRatio': '1:1'}}}],
#    'videos': [],
#    'unknowns': [],
#    'processedCastText': "you've asked for it and now it has arrived. a cast action to tip that sweet ham! install the cast action and let me know what you think. it tips 100 🍖"},
#   'replies': {'count': 503},
#   'reactions': {'count': 1448},
#   'recasts': {'count': 400,
#    'recasters': [{'fid': 508826,
#      'username': 'abbeydinho',
#      'displayName': 'Abbeydinho',
#      'recastHash': '0x00'}]},
#   'watches': {'count': 0},
#   'recast': True,
#   'tags': [{'type': 'channel',
#     'id': 'lp',
#     'name': 'HAM 🍖',
#     'imageUrl': 'https://i.imgur.com/vC00Vn0.png'}],
#   'viewCount': 49500,
#   'quoteCount': 99,
#   'combinedRecastCount': 499,
#   'warpsTipped': 10},
#  {'hash': '0x65b7c29aa68fe07c2561ba75337468d1c30e705a',
#   'threadHash': '0x65b7c29aa68fe07c2561ba75337468d1c30e705a',
#   'parentSource': {'type': 'url',
#    'url': 'chain://eip155:7777777/erc721:0x5d6a07d07354f8793d1ca06280c4adf04767ad7e'},
#   'author': {'fid': 15983,
#    'username': 'jacek',
#    'displayName': 'Jacek 🎩',
#    'pfp': {'url': 'https://i.imgur.com/liviil4.jpg', 'verified': False},
#    'profile': {'bio': {'text': 'Lead $DEGEN | https://www.degen.tips/',
#      'mentions': [],
#      'channelMentions': []},
#     'location': {'placeId': '', 'description': ''}},
#    'followerCount': 38003,
#    'followingCount': 392,
#    'activeOnFcNetwork': True,
#    'badges': [{'type': 'top-user-in-channel',
#      'content': {'topUserInChannel': {'url': 'chain://eip155:7777777/erc721:0x5d6a07d07354f8793d1ca06280c4adf04767ad7e',
#        'warpcastUrl': 'https://warpcast.com/~/channel/degen',
#        'imageUrl': 'https://ipfs.decentralized-content.com/ipfs/bafkreieudzvadtjy36j7x2i73isqw2jmgbwtum3p3eaahn4mnztuzl7y7e',
#        'fastImageUrl': 'https://res.cloudinary.com/merkle-manufactory/image/fetch/c_fill,f_png/https%3A%2F%2Fipfs.decentralized-content.com%2Fipfs%2Fbafkreieudzvadtjy36j7x2i73isqw2jmgbwtum3p3eaahn4mnztuzl7y7e',
#        'channelKey': 'degen'}}}]},
#   'text': '$DEGEN Update: Season 3, Airdrop 2 rewards are now live! Visit Degen.tips to claim yours. Happy Claiming Day to everyone!',
#   'timestamp': 1714543820000,
#   'replies': {'count': 709},
#   'reactions': {'count': 1827},
#   'recasts': {'count': 406,
#    'recasters': [{'fid': 508826,
#      'username': 'abbeydinho',
#      'displayName': 'Abbeydinho',
#      'recastHash': '0x00'}]},
#   'watches': {'count': 0},
#   'recast': True,
#   'tags': [{'type': 'channel',
#     'id': 'degen',
#     'name': 'Degen',
#     'imageUrl': 'https://ipfs.decentralized-content.com/ipfs/bafkreieudzvadtjy36j7x2i73isqw2jmgbwtum3p3eaahn4mnztuzl7y7e'}],
#   'viewCount': 23900,
#   'quoteCount': 214,
#   'combinedRecastCount': 620,
#   'warpsTipped': 10}]

# %%
populate_casts(data['result']['casts'][0])

# %% [markdown]
# # **Binary Search to find the maximum Fid**

# %%
import requests # type: ignore
low = 0
high = 5088080
while low < high:
    mid = (low + high) // 2
    response = requests.get('https://api.warpcast.com/v2/user?fid={}'.format(mid))
    if response.status_code == 200:
        low = mid + 1
    else:
        high = mid
print(high)
# Out:
# 508839

# %%
# !pip install httpx

# %%
api_url = 'https://api.warpcast.com/v2/user?fid=1'
response = requests.get(api_url)

# %%
def populate_casts(cast_data):
    casts_hash = cast_data.get('hash')
    thread_hash = cast_data.get('threadHash')
    parent_source_type = cast_data.get('parentSource', {}).get('type')
    parent_source_url = cast_data.get('parentSource', {}).get('url')
    author_fid = cast_data.get('author', {}).get('fid')
    author_username = cast_data.get('author', {}).get('username')
    author_display_name = cast_data.get('author', {}).get('displayName')
    author_pfp_url = cast_data.get('author', {}).get('pfp', {}).get('url')
    author_pfp_verified = cast_data.get('author', {}).get('pfp', {}).get('verified', False)
    author_profile_bio = cast_data.get('author', {}).get('profile', {}).get('bio', {}).get('text', '')
    author_profile_location_description = cast_data.get('author', {}).get('profile', {}).get('location', {}).get('description', '')
    author_follower_count = cast_data.get('author', {}).get('followerCount', 0)
    author_following_count = cast_data.get('author', {}).get('followingCount', 0)
    author_active_on_fc_network = cast_data.get('author', {}).get('activeOnFcNetwork', False)
    message_text = cast_data.get('text', '')
    timestamp = cast_data.get('timestamp',  datetime.now())
    replies_count = cast_data.get('replies', {}).get('count', 0)
    reactions_count = cast_data.get('reactions', {}).get('count', 0)
    recasts_count = cast_data.get('recasts', {}).get('count', 0)
    watches_count = cast_data.get('watches', {}).get('count', 0)
    quote_count = cast_data.get('quoteCount', 0)  # Corrected spelling
    combined_recast_count = cast_data.get('combinedRecastCount', 0)

# %%
import requests 
from datetime import datetime
fid = 3
limit = 3
response = requests.get("https://client.warpcast.com/v2/casts?fid={}&limit={}".format(fid, limit))
if response.status_code == 200:
    casts_data = response.json()['result']['casts']
    for cast_data in casts_data:
        populate_casts(cast_data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [8], line 9
#       7 casts_data = response.json()['result']['casts']
#       8 for cast_data in casts_data:
# ----> 9     populate_casts(cast_data)
#
# Cell In [6], line 22, in populate_casts(cast_data)
#      20 recasts_count = cast_data.get('recasts', {}).get('count', 0)
#      21 watches_count = cast_data.get('watches', {}).get('count', 0)
# ---> 22 tags_type = cast_data.get('tags', [{}])[0].get('type')
#      23 tags_id = cast_data.get('tags', [{}])[0].get('id')
#      24 tags_name = cast_data.get('tags', [{}])[0].get('name')
#
# IndexError: list index out of range

# %%
for cast_data in casts_data:
    populate_casts(cast_data)
# Out:
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [5], line 2
#       1 for cast_data in casts_data:
# ----> 2     populate_casts(cast_data)
#
# Cell In [3], line 18, in populate_casts(cast_data)
#      16 message_text = cast_data.get('text', '')
#      17 print(cast_data.get('embeds', {}).get('images', [{}]))
# ---> 18 embeds_images_type = cast_data.get('embeds', {}).get('images', [{}])[0].get('type')
#      19 embeds_images_url = cast_data.get('embeds', {}).get('images', [{}])[0].get('url')
#      20 embeds_images_source_url = cast_data.get('embeds', {}).get('images', [{}])[0].get('sourceUrl')
#
# IndexError: list index out of range
